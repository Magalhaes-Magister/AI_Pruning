# %% [markdown]
# # Preparação do Dataset e Treino de Modelos Baseline para CIFAR-10
#
# ## Implementação de Modelos de Referência (MLP e VGG)
#
# ### Objetivo
#
# Este notebook realiza a preparação do dataset **CIFAR-10**, incluindo uma divisão determinística entre treino e validação, seguida do treino e avaliação de dois modelos baseline:
#
# - **MLP (Multilayer Perceptron)**
# - **VGG-11 adaptada ao CIFAR-10**
#
# O principal objetivo é estabelecer modelos de referência robustos para posterior aplicação e avaliação de técnicas de compressão, incluindo **poda estruturada**.

# %% [markdown]
# ---
# # 1. Preparação do Dataset CIFAR-10
#
# Nesta secção é realizada a preparação do dataset **CIFAR-10**, incluindo:
#
# - Download e carregamento dos dados
# - Verificação visual das classes
# - Divisão determinística entre treino e validação
# - Aplicação de transformações e normalização
# - Criação dos *DataLoaders*
#
# O objetivo é garantir **reprodutibilidade experimental**, assegurando que todos os modelos são treinados sobre a mesma divisão de dados.

# %% [markdown]
# ## 1.1. Configuração do Ambiente e Inicialização
#
# Nesta etapa são importadas as bibliotecas necessárias para:
#
# - Construção e treino de redes neuronais (**PyTorch**)
# - Gestão do dataset (**TorchVision**)
# - Divisão estratificada dos dados (**Scikit-learn**)
# - Visualização gráfica (**Matplotlib**)
# - Avaliação quantitativa do desempenho
#
# É também configurado o dispositivo de execução (**CPU ou GPU**) para acelerar o treino dos modelos quando disponível.

# %%
import torch
import torch.nn as nn
import torchvision
from torchvision.transforms import v2
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np
import random
from pathlib import Path
from tqdm import tqdm
from torch.utils.data import DataLoader, Subset
from collections import defaultdict
import time
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    balanced_accuracy_score,
    cohen_kappa_score,
    matthews_corrcoef
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Out:
# cuda

# %% [markdown]
# ## 1.2. Download e Carregamento do Dataset CIFAR-10
#
# O dataset **CIFAR-10** é carregado através da biblioteca TorchVision.
#
# Este conjunto de dados contém:
#
# - **60 000 imagens RGB**
# - Resolução de **32×32 píxeis**
# - **10 classes distintas**
#
# Distribuídas por:
#
# - **50 000 imagens de treino**
# - **10 000 imagens de teste**
#
# As imagens abrangem categorias como aviões, automóveis, pássaros, gatos, cães e outros objectos do quotidiano.

# %%
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %% [markdown]
# ## 1.3. Visualização e Verificação das Classes
#
# Antes do treino dos modelos, é realizada uma inspecção visual do dataset.
#
# O objetivo desta etapa é:
#
# - Confirmar que os dados foram carregados correctamente
# - Verificar a consistência visual das diferentes categorias
# - Observar exemplos representativos de cada classe
#
# Esta validação inicial ajuda a identificar possíveis problemas de carregamento ou pré-processamento.

# %%
class_samples = {}
for img, label in trainset:
    if label not in class_samples:
        class_samples[label] = img
    if len(class_samples) == len(classes):
        break

fig, axes = plt.subplots(2, 5, figsize=(15, 6))
for idx, (label, img) in enumerate(sorted(class_samples.items())):
    ax = axes[idx // 5, idx % 5]
    ax.imshow(img)
    ax.set_title(classes[label])
    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 1.4. Divisão Estratificada Determinística (Treino e Validação)
#
# Para garantir uma avaliação consistente do desempenho dos modelos, o conjunto de treino é dividido em:
#
# - **Treino**
# - **Validação**
#
# A divisão é realizada de forma:
#
# ### Estratificada
# Preserva a distribuição original das classes em ambos os subconjuntos.
#
# ### Determinística
# Utiliza uma seed fixa, assegurando que todas as experiências são reproduzíveis.
#
# Esta abordagem é particularmente importante para experiências futuras de poda e compressão, garantindo comparabilidade entre resultados.

# %% [markdown]
# ### Transformações e Normalização dos Dados
#
# São aplicadas transformações ao dataset com o objetivo de preparar as imagens para treino.
#
# Estas incluem:
#
# - Conversão para tensores
# - Conversão para precisão `float32`
# - Normalização dos canais RGB
#
# A normalização ajuda a estabilizar o treino e melhora a convergência dos algoritmos de optimização.

# %%
transform = v2.Compose([
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize(
        mean=(0.4914, 0.4822, 0.4465),
        std=(0.2470, 0.2435, 0.2616))])

full_trainset  = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

targets = np.array(full_trainset.targets)
perc_val = 15
val_per_class = perc_val*50
train_indices = []
val_indices = []

for class_id in range(10):
    class_indices = np.where(targets == class_id)[0]

    # deterministic shuffle
    rng = np.random.default_rng(SEED + class_id)
    rng.shuffle(class_indices)

    val_class_indices = class_indices[:val_per_class]
    train_class_indices = class_indices[val_per_class:]

    val_indices.extend(val_class_indices)
    train_indices.extend(train_class_indices)


trainset = Subset(full_trainset, train_indices)
valset = Subset(full_trainset, val_indices)

batch_size = 64

valloader = DataLoader(valset, batch_size=batch_size, shuffle=False, num_workers=2)
trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)
testloader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# %%
val_targets = targets[val_indices]

for i in range(10):
    print(f"Class {i}: {(val_targets == i).sum()}")
# Out:
# Class 0: 750
# Class 1: 750
# Class 2: 750
# Class 3: 750
# Class 4: 750
# Class 5: 750
# Class 6: 750
# Class 7: 750
# Class 8: 750
# Class 9: 750

# %% [markdown]
# ## 1.5. Persistência da Partição de Dados
#
# Os índices da divisão treino/validação são guardados localmente para reutilização futura.
#
# Esta prática permite:
#
# - Reproduzir exactamente as mesmas experiências
# - Garantir comparabilidade entre modelos
# - Evitar diferenças introduzidas por novos *splits* aleatórios
#
# O ficheiro exportado pode posteriormente ser reutilizado em notebooks de poda e avaliação experimental.

# %%
train_indices = np.array(train_indices)
val_indices = np.array(val_indices)

torch.save(
    {
        "train_indices": train_indices,
        "val_indices": val_indices,
        "seed": SEED
    },
    "data/cifar10_split.pt"
)
print("Split saved.")
# Out:
# Split saved.

# %%
# To load
'''
from torch.utils.data import Subset

split = torch.load("cifar10_split.pt")

train_indices = split["train_indices"]
val_indices = split["val_indices"]

trainset = Subset(full_trainset, train_indices)
valset = Subset(full_trainset, val_indices)

valloader = DataLoader(valset, batch_size=batch_size, shuffle=False, num_workers=2)
trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)
'''

# %% [markdown]
# ---
# # 2. Criação e Treino dos Modelos Baseline
#
# Após a preparação dos dados, são implementados dois modelos de referência (*baseline*):
#
# ## MLP (Multilayer Perceptron)
#
# Uma arquitetura totalmente conectada, utilizada como referência simples para comparação.
#
# ## VGG-11 Adaptada ao CIFAR-10
#
# Uma arquitetura convolucional profunda baseada na família **VGG**, modificada para operar sobre imagens de dimensão **32×32**.
#
# Estes modelos servirão como base para estudos posteriores de:
#
# - Compressão
# - Poda estruturada
# - Redução de complexidade computacional

# %% [markdown]
# ## 2.1 Modelo Fully Connected: MLP
#
# O primeiro modelo implementado é um **Perceptron Multicamadas (MLP)**.
#
# Por se tratar de uma arquitetura totalmente conectada, as imagens são achatadas (*flattened*) antes de serem processadas.
#
# Apesar da sua simplicidade, este modelo fornece uma baseline útil para:
#
# - Comparação de desempenho
# - Estudos de compressão
# - Avaliação do impacto da poda

# %%
# ============================================================================
# 1. PERCEPTRON MULTICAMADAS (MLP)
# ============================================================================
class CIFAR10MLP(nn.Module):
    """
    Rede de neurónios densa para isolar o efeito da poda em ligações totalmente 
    conectadas (Fully Connected), afetando diretamente as matrizes de pesos.
    """
    def __init__(self, input_dim=3 * 32 * 32, num_classes=10):
        super(CIFAR10MLP, self).__init__()
        
        self.classifier = nn.Sequential(
            nn.Flatten(),

            nn.Linear(input_dim, 2048),
            nn.BatchNorm1d(2048),
            nn.ReLU(),
            nn.Dropout(0.3),

            nn.Linear(2048, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(),
            nn.Dropout(0.3),

            nn.Linear(1024, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),
            nn.Dropout(0.2),

            nn.Linear(512, num_classes)
        )
        
    def forward(self, x):
        return self.classifier(x)

# %% [markdown]
# ## 2.2 Arquitetura Convolucional: VGG-11 Adaptada
#
# O segundo modelo corresponde a uma versão adaptada da arquitetura **VGG-11**, originalmente proposta para tarefas de visão computacional.
#
# Foram efectuadas adaptações para o dataset CIFAR-10:
#
# - Ajuste das dimensões de entrada
# - Camadas compatíveis com imagens de 32×32
# - Classificador final com 10 categorias
#
# As redes convolucionais são particularmente adequadas para classificação de imagens, devido à sua capacidade de extrair padrões espaciais relevantes.

# %%
# ============================================================================
# 2. VISUAL GEOMETRY GROUP (VGG-11 adaptada para CIFAR-10)
# ============================================================================
class CIFAR10VGG(nn.Module):
    """
    Rede convolucional profunda (baseada na VGG-11) ideal para testar a poda 
    estruturada de filtros e canais devido à sua elevada densidade de parâmetros.
    """
    def __init__(self, num_classes=10):
        super(CIFAR10VGG, self).__init__()
        
        # Configuração da VGG-11: números representam canais de saída, 'M' é MaxPool
        # Ajustada para CIFAR-10 para manter mapas de características viáveis (32x32 -> 1x1)
        self.cfg = [64, 'M', 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M']
        
        self.features = self._make_layers(self.cfg)

        self.avgpool = nn.AdaptiveAvgPool2d((1,1))
        
        # Classificador linear simplificado para o CIFAR-10 pós-convoluções
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(512, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(512, num_classes)
        )
        
    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = self.classifier(x)
        return x
        
    def _make_layers(self, cfg):
        layers = []
        in_channels = 3  # Entrada RGB do CIFAR-10
        
        for x in cfg:
            if x == 'M':
                layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
            else:
                layers += [
                    nn.Conv2d(in_channels, x, kernel_size=3, padding=1),
                    nn.BatchNorm2d(x), # Crucial para estabilidade antes/pós poda
                    nn.ReLU(inplace=True)
                ]
                in_channels = x
                
        return nn.Sequential(*layers)

# %% [markdown]
# ### Verificação da Arquitetura dos Modelos
#
# Antes do treino, é realizada uma verificação das dimensões de entrada e saída dos modelos.
#
# Este teste assegura que:
#
# - O *forward pass* funciona correctamente
# - As dimensões são compatíveis
# - Não existem erros estruturais na arquitetura

# %%
# Simulação de um lote (batch) de 4 imagens do CIFAR-10
mock_input = torch.randn(4, 3, 32, 32)

mlp_model = CIFAR10MLP()
vgg_model = CIFAR10VGG()

print("## Verificação das Arquiteturas ##")
print(f"MLP Output Shape: {mlp_model(mock_input).shape}")
print(f"VGG Output Shape: {vgg_model(mock_input).shape}")

mlp_total_params = sum(p.numel() for p in mlp_model.parameters() if p.requires_grad)
vgg_total_params = sum(p.numel() for p in vgg_model.parameters() if p.requires_grad)

print("\n## Densidade de Parâmetros (Alvos de Poda) ##")
print(f"Total de parâmetros treináveis no MLP: {mlp_total_params:,}")
print(f"Total de parâmetros treináveis na VGG: {vgg_total_params:,}")
# Out:
# ## Verificação das Arquiteturas ##
# MLP Output Shape: torch.Size([4, 10])
# VGG Output Shape: torch.Size([4, 10])
#
# ## Densidade de Parâmetros (Alvos de Poda) ##
# Total de parâmetros treináveis no MLP: 8,928,778
# Total de parâmetros treináveis na VGG: 9,493,770

# %% [markdown]
# ## 2.3. Definição do Pipeline de Treino e Avaliação
#
# São implementadas funções auxiliares responsáveis por:
#
# ### Treino do Modelo
# Executar o processo iterativo de optimização dos pesos.
#
# ### Avaliação
# Medir o desempenho sobre conjuntos de validação e teste.
#
# ### Monitorização
# Guardar métricas relevantes ao longo do treino, incluindo:
#
# - Loss de treino
# - Loss de validação
# - Accuracy

# %%
def train_model(model, trainloader, valloader, epochs=10, lr=1e-3, device=device):
    model = model.to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)

    train_losses = []
    val_losses = []
    val_accuracies = []

    for epoch in range(epochs):

        # -----------------
        # TRAIN
        # -----------------
        model.train()
        running_loss = 0.0

        for images, labels in tqdm(trainloader):

            images = images.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()

            outputs = model(images)
            loss = criterion(outputs, labels)

            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        train_loss = running_loss / len(trainloader)
        train_losses.append(train_loss)

        # -----------------
        # VALIDATION
        # -----------------
        model.eval()

        running_val_loss = 0.0
        correct = 0
        total = 0

        with torch.no_grad():
            for images, labels in valloader:

                images = images.to(device)
                labels = labels.to(device)

                outputs = model(images)
                loss = criterion(outputs, labels)

                running_val_loss += loss.item()

                _, predicted = torch.max(outputs, 1)

                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        val_loss = running_val_loss / len(valloader)
        accuracy = 100 * correct / total

        val_losses.append(val_loss)
        val_accuracies.append(accuracy)

        print(
            f"Epoch [{epoch+1}/{epochs}] "
            f"Train Loss: {train_loss:.4f} | "
            f"Val Loss: {val_loss:.4f} | "
            f"Val Acc: {accuracy:.2f}%"
        )

    return model, train_losses, val_losses, val_accuracies

# %%
def evaluate_model(model, loader, criterion=None, device=None):
    """
    Avalia o modelo calculando métricas de classificação, perda,
    latência total da inferência (ms) e pico de consumo VRAM (MB).
    """
    if device is None:
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    model.eval()
    y_true = []
    y_pred = []
    y_probs = []
    total_loss = 0.0

    # Reinicia estatísticas de memória para obter o pico exato desta execução
    if torch.cuda.is_available() and device.type == 'cuda':
        torch.cuda.reset_peak_memory_stats(device)

    # Inicializa cronómetro de alta precisão
    start_time = time.perf_counter()

    with torch.no_grad():
        for images, labels in loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)

            if criterion is not None:
                loss = criterion(outputs, labels)
                total_loss += loss.item() * images.size(0)

            # predicted class
            _, predicted = torch.max(outputs, 1)

            # probabilities
            probs = torch.softmax(outputs, dim=1)

            y_true.extend(labels.cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())
            y_probs.extend(probs.cpu().numpy())
    
    end_time = time.perf_counter()

    # Cálculos de Hardware (Latência em milissegundos e VRAM em Megabytes)
    latency_ms = (end_time - start_time) * 1000
    vram_mb = torch.cuda.max_memory_allocated(device) / (1024 * 1024) if torch.cuda.is_available() and device.type == 'cuda' else 0.0

    metrics = compute_metrics(y_true, y_pred, vram=vram_mb, latency=latency_ms)

    if criterion is not None:
        metrics["loss"] = total_loss / len(loader.dataset)

    return y_true, y_pred, metrics

def compute_metrics(y_true, y_pred, vram=None, latency=None):
    """
    Calcula as métricas clássicas do Scikit-Learn e anexa opcionalmente
    a pegada de memória VRAM e a latência obtidas.
    """
    metrics = {
        "accuracy": accuracy_score(y_true, y_pred),
        "balanced_accuracy":balanced_accuracy_score(y_true, y_pred),
        "precision_macro":precision_score(y_true,y_pred,average="macro",zero_division=0),
        "precision_weighted":precision_score(y_true,y_pred,average="weighted",zero_division=0),
        "recall_macro":recall_score(y_true,y_pred,average="macro",zero_division=0),
        "recall_weighted":recall_score(y_true,y_pred,average="weighted",zero_division=0),
        "f1_macro":f1_score(y_true,y_pred,average="macro"),
        "f1_weighted":f1_score(y_true,y_pred,average="weighted"),
        "cohen_kappa":cohen_kappa_score(y_true, y_pred),
        "mcc":matthews_corrcoef(y_true, y_pred)
    }

    if vram is not None:
        metrics["vram"] = vram
    if latency is not None:
        metrics["latency"] = latency

    return metrics

# %% [markdown]
# ## 2.4. Treino do Modelo MLP
#
# Nesta etapa é treinado o modelo **CIFAR10MLP**.
#
# O treino é realizado utilizando o conjunto de treino, enquanto o conjunto de validação é usado para monitorizar a capacidade de generalização do modelo.
#
# O objectivo é estabelecer uma baseline simples de desempenho para comparação futura.

# %%
mlp_model = CIFAR10MLP()

mlp_model, mlp_train_loss, mlp_val_loss, mlp_acc = train_model(
    mlp_model,
    trainloader,
    valloader,
    epochs=20,
    lr=1e-3
)
# Out:
# ...
# 100%|██████████| 665/665 [00:14<00:00, 46.00it/s]
# Epoch [1/20] Train Loss: 1.7052 | Val Loss: 1.5074 | Val Acc: 46.11%
# ...
# 100%|██████████| 665/665 [00:14<00:00, 46.00it/s]
# Epoch [1/20] Train Loss: 1.7052 | Val Loss: 1.5074 | Val Acc: 46.11%
# 100%|██████████| 665/665 [00:14<00:00, 46.06it/s]
# Epoch [2/20] Train Loss: 1.5054 | Val Loss: 1.4067 | Val Acc: 50.23%
# ...
# 100%|██████████| 665/665 [00:14<00:00, 46.00it/s]
# Epoch [1/20] Train Loss: 1.7052 | Val Loss: 1.5074 | Val Acc: 46.11%
# 100%|██████████| 665/665 [00:14<00:00, 46.06it/s]
# Epoch [2/20] Train Loss: 1.5054 | Val Loss: 1.4067 | Val Acc: 50.23%
# 100%|██████████| 665/665 [00:15<00:00, 43.23it/s]
# Epoch [3/20] Train Loss: 1.4217 | Val Loss: 1.3487 | Val Acc: 51.41%
# ...
# 100%|██████████| 665/665 [00:14<00:00, 46.00it/s]
# Epoch [1/20] Train Loss: 1.7052 | Val Loss: 1.5074 | Val Acc: 46.11%
# 100%|██████████| 665/665 [00:14<00:00, 46.06it/s]
# Epoch [2/20] Train Loss: 1.5054 | Val Loss: 1.4067 | Val Acc: 50.23%
# ...

# %% [markdown]
# ## 2.5. Treino do Modelo VGG-11
#
# É agora treinada a arquitetura convolucional **VGG adaptada ao CIFAR-10**.
#
# Dada a sua maior profundidade e capacidade de extracção de características espaciais, espera-se um desempenho superior ao MLP na tarefa de classificação de imagens.

# %%
vgg_model = CIFAR10VGG()

vgg_model, vgg_train_loss, vgg_val_loss, vgg_acc = train_model(
    vgg_model,
    trainloader,
    valloader,
    epochs=20,
    lr=1e-4
)
# Out:
# ...
# 100%|██████████| 665/665 [00:20<00:00, 32.80it/s]
# Epoch [1/20] Train Loss: 1.2455 | Val Loss: 0.9813 | Val Acc: 65.32%
# ...
# 100%|██████████| 665/665 [00:20<00:00, 32.80it/s]
# Epoch [1/20] Train Loss: 1.2455 | Val Loss: 0.9813 | Val Acc: 65.32%
# 100%|██████████| 665/665 [00:20<00:00, 32.63it/s]
# Epoch [2/20] Train Loss: 0.8041 | Val Loss: 0.9807 | Val Acc: 65.96%
# ...
# 100%|██████████| 665/665 [00:20<00:00, 32.80it/s]
# Epoch [1/20] Train Loss: 1.2455 | Val Loss: 0.9813 | Val Acc: 65.32%
# 100%|██████████| 665/665 [00:20<00:00, 32.63it/s]
# Epoch [2/20] Train Loss: 0.8041 | Val Loss: 0.9807 | Val Acc: 65.96%
# 100%|██████████| 665/665 [00:20<00:00, 32.36it/s]
# Epoch [3/20] Train Loss: 0.5952 | Val Loss: 0.7420 | Val Acc: 74.79%
# ...
# 100%|██████████| 665/665 [00:20<00:00, 32.80it/s]
# Epoch [1/20] Train Loss: 1.2455 | Val Loss: 0.9813 | Val Acc: 65.32%
# 100%|██████████| 665/665 [00:20<00:00, 32.63it/s]
# Epoch [2/20] Train Loss: 0.8041 | Val Loss: 0.9807 | Val Acc: 65.96%
# ...

# %% [markdown]
# ---
# # 3. Avaliação Quantitativa dos Modelos
#
# Após o treino, ambos os modelos são avaliados no conjunto de teste.
#
# São analisadas métricas de classificação para medir:
#
# - Desempenho global
# - Robustez entre classes
# - Capacidade de generalização
#
# Esta etapa permite comparar directamente as arquiteturas baseline.

# %%
mlp_true, mlp_pred, mlp_probs = evaluate_model(
    mlp_model,
    testloader,
    device
)
vgg_true, vgg_pred, vgg_probs = evaluate_model(
    vgg_model,
    testloader,
    device
)

# %% [markdown]
# ## 3.1 Avaliação do Baseline MLP
#
# O modelo MLP é avaliado no conjunto de teste.
#
# São calculadas métricas de desempenho e guardados os pesos treinados para reutilização posterior em experiências de poda.

# %%
mlp_metrics = compute_metrics(
    mlp_true,
    mlp_pred
)

for key, value in mlp_metrics.items():
    print(f"{key}: {value:.4f}")
# Out:
# accuracy: 0.5732
# balanced_accuracy: 0.5732
# precision_macro: 0.5799
# precision_weighted: 0.5799
# recall_macro: 0.5732
# recall_weighted: 0.5732
# f1_macro: 0.5752
# f1_weighted: 0.5752
# cohen_kappa: 0.5258
# mcc: 0.5261

# %% [markdown]
# ## 3.2 Avaliação do Baseline VGG
#
# A arquitetura VGG é avaliada no conjunto de teste utilizando as mesmas métricas do modelo MLP.
#
# Os resultados obtidos servirão como referência principal para futuras técnicas de compressão e poda estruturada.

# %%
vgg_metrics = compute_metrics(
    vgg_true,
    vgg_pred
)

for key, value in vgg_metrics.items():
    print(f"{key}: {value:.4f}")
# Out:
# accuracy: 0.7852
# balanced_accuracy: 0.7852
# precision_macro: 0.7906
# precision_weighted: 0.7906
# recall_macro: 0.7852
# recall_weighted: 0.7852
# f1_macro: 0.7838
# f1_weighted: 0.7838
# cohen_kappa: 0.7613
# mcc: 0.7623

# %% [markdown]
# ## 3.3 Comparação de Métricas entre Modelos
#
# Os resultados quantitativos dos dois modelos são organizados numa tabela comparativa.
#
# Esta análise permite observar diferenças entre:
#
# - Accuracy
# - Precisão
# - Recall
# - F1-score
# - Robustez global
#
# A comparação ajuda a identificar qual o modelo mais adequado como baseline experimental.

# %%
import pandas as pd

# Criar DataFrame de comparação
comparison_df = pd.DataFrame({
    "MLP Baseline": mlp_metrics,
    "VGG Baseline": vgg_metrics
})

print("\nTabela Comparativa de Métricas no Teste:")
display(comparison_df)

# Plotar perdas
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(mlp_train_loss, label="Treino MLP", color="#1F77B4", linewidth=2)
plt.plot(mlp_val_loss, label="Validação MLP", color="#FF7F0E", linestyle="--", linewidth=2)
plt.title("Curvas de Loss - MLP Baseline", fontsize=13, fontweight='bold')
plt.xlabel("Época", fontsize=11)
plt.ylabel("Loss", fontsize=11)
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(1, 2, 2)
plt.plot(vgg_train_loss, label="Treino VGG", color="#2CA02C", linewidth=2)
plt.plot(vgg_val_loss, label="Validação VGG", color="#D62728", linestyle="--", linewidth=2)
plt.title("Curvas de Loss - VGG Baseline", fontsize=13, fontweight='bold')
plt.xlabel("Época", fontsize=11)
plt.ylabel("Loss", fontsize=11)
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Tabela Comparativa de Métricas no Teste:
#                     MLP Baseline  VGG Baseline
# accuracy                0.572600      0.811300
# balanced_accuracy       0.572600      0.811300
# precision_macro         0.572232      0.816118
# precision_weighted      0.572232      0.816118
# recall_macro            0.572600      0.811300
# recall_weighted         0.572600      0.811300
# f1_macro                0.570818      0.810954
# f1_weighted             0.570818      0.810954
# cohen_kappa             0.525111      0.790333
# mcc                     0.525454      0.790913

# %% [markdown]
# ### Desempenho por Classe
#
# Para além das métricas globais, é analisado o desempenho individual por categoria do CIFAR-10.
#
# Esta análise permite identificar:
#
# - Classes mais difíceis de classificar
# - Possíveis enviesamentos
# - Diferenças de generalização entre arquiteturas

# %%
print(classification_report(
    mlp_true,
    mlp_pred,
    target_names=classes
))
# Out:
#               precision    recall  f1-score   support
#
#        plane       0.64      0.65      0.65      1000
#          car       0.72      0.65      0.68      1000
#         bird       0.48      0.47      0.47      1000
#          cat       0.37      0.43      0.40      1000
#         deer       0.48      0.54      0.50      1000
#          dog       0.49      0.45      0.47      1000
#         frog       0.59      0.65      0.62      1000
#        horse       0.69      0.60      0.64      1000
#         ship       0.68      0.71      0.69      1000
#        truck       0.66      0.58      0.62      1000
#
#     accuracy                           0.57     10000
#    macro avg       0.58      0.57      0.58     10000
# weighted avg       0.58      0.57      0.58     10000

# %%
print(classification_report(
    vgg_true,
    vgg_pred,
    target_names=classes
))
# Out:
#               precision    recall  f1-score   support
#
#        plane       0.73      0.88      0.80      1000
#          car       0.94      0.85      0.89      1000
#         bird       0.80      0.62      0.70      1000
#          cat       0.68      0.57      0.62      1000
#         deer       0.80      0.71      0.75      1000
#          dog       0.66      0.78      0.71      1000
#         frog       0.78      0.87      0.83      1000
#        horse       0.74      0.87      0.80      1000
#         ship       0.87      0.86      0.87      1000
#        truck       0.91      0.84      0.87      1000
#
#     accuracy                           0.79     10000
#    macro avg       0.79      0.79      0.78     10000
# weighted avg       0.79      0.79      0.78     10000

# %% [markdown]
# ### Matrizes de Confusão
#
# As matrizes de confusão fornecem uma representação detalhada dos erros de classificação.
#
# Estas visualizações permitem identificar:
#
# - Classes frequentemente confundidas
# - Padrões de erro do modelo
# - Dificuldades específicas de reconhecimento visual

# %%
def plot_confusion_matrix(y_true, y_pred, classes, title):
    cm = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(8,8))
    disp = ConfusionMatrixDisplay(
        confusion_matrix=cm,
        display_labels=classes
    )
    disp.plot(
        cmap="Blues",
        ax=ax,
        xticks_rotation=45,
        colorbar=False
    )
    plt.title(title)
    plt.show()

# %%
plot_confusion_matrix(
    mlp_true,
    mlp_pred,
    classes,
    "MLP Confusion Matrix"
)

# %%
plot_confusion_matrix(
    vgg_true,
    vgg_pred,
    classes,
    "VGG Confusion Matrix"
)

# %% [markdown]
# ### Visualização de Predições
#
# São apresentados exemplos de imagens do conjunto de teste juntamente com as respectivas previsões dos modelos.
#
# Esta análise qualitativa complementa as métricas quantitativas, permitindo observar:
#
# - Casos correctamente classificados
# - Exemplos ambíguos
# - Tipos de erro mais frequentes

# %%
def show_predictions(model, loader, n_images=8):
    model.eval()
    images, labels = next(iter(loader))
    images = images[:n_images].to(device)
    labels = labels[:n_images]
    with torch.no_grad():
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)

    images = images.cpu()
    fig, axes = plt.subplots(1, n_images, figsize=(16,4))
    for i in range(n_images):
        img = images[i]

        # unnormalize
        img = img * 0.5 + 0.5
        img = img.permute(1,2,0)

        axes[i].imshow(img)
        axes[i].axis("off")

        true_label = classes[labels[i]]
        pred_label = classes[predicted[i]]

        color = "green" if labels[i] == predicted[i] else "red"

        axes[i].set_title(
            f"T:{true_label}\nP:{pred_label}",
            color=color,
            fontsize=9
        )

    plt.show()

# %%
show_predictions(mlp_model, testloader)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.39153773..1.5471395].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.49473685..1.4979502].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.4629833..1.535427].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.22441113..1.4005105].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.4391681..1.2814069].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.45793372..1.1802653].
# ...

# %%
show_predictions(vgg_model, testloader)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.39153773..1.5471395].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.49473685..1.4979502].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.4629833..1.535427].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.22441113..1.4005105].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.4391681..1.2814069].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.45793372..1.1802653].
# ...

# %% [markdown]
# ---
# # 4. Persistência dos Modelos Treinados
#
# Os modelos treinados são guardados localmente para reutilização futura.
#
# Esta abordagem permite:
#
# - Evitar novo treino desnecessário
# - Reproduzir experiências
# - Aplicar técnicas de poda sobre modelos previamente treinados
# - Garantir consistência experimental

# %%
models_dir = Path('model_dir')
models_dir.mkdir(exist_ok=True)

PATH_MLP = models_dir / 'cifar_mlp.pt'
PATH_VGG = models_dir / 'cifar_vgg.pt'

# %%
torch.save(vgg_model, PATH_VGG)
torch.save(mlp_model, PATH_MLP)

# %%
mlp_model = torch.load(PATH_MLP, weights_only=False)
mlp_model.eval()
vgg_model = torch.load(PATH_VGG, weights_only=False)
vgg_model.eval()
# Out:
# CIFAR10VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU(inplace=True)
#     (11): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...
